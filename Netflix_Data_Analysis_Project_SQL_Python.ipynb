# %%
### Import Required Libraries.
import kaggle
import zipfile
import pandas as pd
import sqlalchemy

# %%
### Using kaggle API to download dataset
# !kaggle datasets download -d shivamb/netflix-shows
# Out:
# Dataset URL: https://www.kaggle.com/datasets/shivamb/netflix-shows
# License(s): CC0-1.0
# netflix-shows.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
### Using zipfile library to download 
unzip_data = zipfile.ZipFile("netflix-shows.zip")
unzip_data.extractall()
unzip_data.close()

# %%
### Read CSV file into pandas dataframe
df = pd.read_csv("netflix_titles.csv")

# %%
### Changing column names cast and type to cast_members and show_type
df = df.rename(columns = {"cast":"cast_members"})
df = df.rename(columns = {"type":"show_type"})

# %%
df.head()
# Out:
#   show_id show_type                  title         director  \
# 0      s1     Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2   TV Show          Blood & Water              NaN
# 2      s3   TV Show              Ganglands  Julien Leclercq
# 3      s4   TV Show  Jailbirds New Orleans              NaN
# 4      s5   TV Show           Kota Factory              NaN
#
#                                         cast_members        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
### Create SQLAlchemy engine.
engine = sqlalchemy.create_engine("postgresql+psycopg2://postgres:Ganesh1912@localhost:5433/Netflix_Data_Analysis_Project")
conn = engine.connect()

# %%
### Load pandas dataframe to PostgreSQL table 'netflix_raw'
df.to_sql('netflix_raw',con=conn,index=False,if_exists='append')
conn.close()
